# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("updated_f1_lap_time_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  year  round  circuit_name  circuit_country  driver_id  \
# 0           0  2010      1             0                0          0
# 1           1  2010      1             0                0          1
# 2           2  2010      1             0                0          2
# 3           3  2010      1             0                0          3
# 4           4  2010      1             0                0          4
#
#    lap_number  estimated_horsepower  car_weight  track_temperature  \
# 0           1              0.072289    0.737374           0.500000
# 1           1              0.040161    0.828283           0.500000
# 2           1              0.975904    0.878788           0.958333
# 3           1              0.248996    0.565657           0.708333
# 4           1              0.983936    0.282828           0.375000
#
#    driving_aggression  fuel_load_percent  lap_time_sec  tire_compound_hard  \
# ...
